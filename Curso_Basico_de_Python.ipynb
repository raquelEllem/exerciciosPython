# %% [markdown]
# <a href="https://colab.research.google.com/github/raquelEllem/exerciciosPython/blob/main/Curso_Basico_de_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Passo a Passo de solução do Desafio**
#
# 1) Percorrer todos os arquivos da pasta base de dados (pasta Vendas)
#
# 2) Importar as bases de dados de vendas
#
# 3) Tratar / compilar as bases de dados
#
# 4) Calcular o produto mais vendido (em quantidade)
#
# 5) Calcular o produto que mais faturou (em faturamento)
#
# 6) Calcular a loja/cidade que mais vendeu (em faturamento) - criar um gráfico/dashboard

# %%
import os
import pandas as pd
import plotly.express as px

#importar a base de dados
lista_arquivo = os.listdir("/content/drive/MyDrive/Curso Básico de Pyhton/Vendas")

tabela_total = pd.DataFrame()

for arquivo in lista_arquivo:
  if "Vendas" in arquivo.capitalize():
    #importar o arquivo
    tabela = pd.read_csv(f"/content/drive/MyDrive/Curso Básico de Pyhton/Vendas/{arquivo}")
    # compilar as bases de dados
    tabela_total = tabela_total.append(tabela)

# calcular o produto mais vendido
tabela_produtos = tabela_total.groupby('Produto').sum()
#display(tabela_produtos)
tabela_produtos = tabela_produtos[['Quantidade Vendida', 'Preco Unitario']].sort_values(by='Quantidade Vendida', ascending=False)
#display(tabela_produtos)

# calcular o produto que mais faturou
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']

tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[['Faturamento']].sort_values(by='Faturamento', ascending=False)
#display(tabela_faturamento)

#calcular a loja que mais vendeu
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']].sort_values(by='Faturamento', ascending=False)
display(tabela_lojas)

#criar gráfico
grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y='Faturamento')
grafico.show()
# Out:
#                 Faturamento
# Loja
# São Paulo          22098300
# Rio de Janeiro     14867800
# Fortaleza          14087900
# Salvador           13111300
# Goiás               7441800
# Recife              7303000
# Curitiba            7060500
# Porto Alegre        6868600
# Belo Horizonte      6480300
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
